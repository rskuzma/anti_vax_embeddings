# %% [markdown]
# # Make local embeddings for each document
# - global embeddings meant all articles were clustered together. let's try local

# %%
import pickle
import pandas as pd, numpy as np

import gensim
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
### load df

DATA_PATH = './data/cleaned/'
DF_NAME = 'concatenated_df_cleaned_glove.pkl'

with open(DATA_PATH + DF_NAME, 'rb') as f:
    df = pickle.load(f)

# %%
class TaggedDocumentIterator(object):
    def __init__(self, doc_list, labels_list):
        self.labels_list = labels_list
        self.doc_list = doc_list
    def __iter__(self):
        for idx, doc in enumerate(self.doc_list):
            yield TaggedDocument(words=doc, tags=[self.labels_list[idx]])

# %%
df.head()
# Out:
#                   created_at  \
# 0  2020-01-31 23:08:33+00:00
# 1  2020-01-31 23:11:29+00:00
# 2  2020-01-31 23:12:03+00:00
# 3  2020-01-31 23:35:42+00:00
# 4  2020-01-31 23:37:23+00:00
#
#                                                 user               id_str  \
# 0  {'id': 19031057, 'id_str': '19031057', 'name':...  1223382589689356288
# 1  {'id': 798925214, 'id_str': '798925214', 'name...  1223383328843280384
# 2  {'id': 806144538049970176, 'id_str': '80614453...  1223383471999127552
# 3  {'id': 61298849, 'id_str': '61298849', 'name':...  1223389423045206016
# 4  {'id': 1152822375567654912, 'id_str': '1152822...  1223389844719599616
#
#                                     retweeted_status              Hash words  \
# 0                                                NaN            #coronavirus
# 1  {'created_at': 'Fri Jan 31 20:41:20 +0000 2020...  #coronavirus #vaccine:
# 2                                                NaN             No hashtags
# 3  {'created_at': 'Tue Jan 28 18:26:16 +0000 2020...             No hashtags
# 4                                                NaN             No hashtags
#
#                                                 link  \
# 0  https://twitter.com/user/status/12233825896893...
# 1  https://twitter.com/user/status/12233833288432...
# 2  https://twitter.com/user/status/12233834719991...
# 3  https://twitter.com/user/status/12233894230452...
# 4  https://twitter.com/user/status/12233898447195...
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'coronavirus', 'indices...
# 1  {'hashtags': [{'text': 'Coronavirus', 'indices...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                 Topic Label  \
# 0   (43, 0.999852366207409)
# 1   (6, 0.9883827140131066)
# 2  (74, 0.9999928079220538)
# 3  (36, 0.9999993854913211)
# 4  (74, 0.9999985797901156)
#
#                                                 urls  no_link  ...  \
# 0  [https://www.kron4.com/news/national/when-will...    False  ...
# 1  [https://www.cnbc.com/2020/01/31/coronavirus-w...    False  ...
# 2  [https://www.businessinsider.com/australia-suc...    False  ...
# 3  [https://www.greenmedinfo.com/blog/examining-r...    False  ...
# 4  [https://www.dailymail.co.uk/news/article-7952...    False  ...
#
#    month_year week_month_year              user_id cluster is_retweet  \
# 0     2020-01               5             19031057      43      False
# 1     2020-01               5            798925214       6       True
# 2     2020-01               5   806144538049970176      74      False
# 3     2020-01               5             61298849      36       True
# 4     2020-01               5  1152822375567654912      74      False
#
#                  hashtags link_shorteners  \
# 0           [coronavirus]         [False]
# 1  [Coronavirus, vaccine]         [False]
# 2                  [None]         [False]
# 3                  [None]         [False]
# 4                  [None]          [True]
#
#                                         article_text  \
# 0   KRON4 by: Aubree Gordon, University of Michig...
# 1   U.S. and international health officials are s...
# 2   A leading-edge research firm focused on digit...
# 3    Mr. Kennedy is in very safe territory by rep...
# 4   By Kylie Stevens and Stephen Gibbs and Nic Wh...
#
#                                 article_text_cleaned  \
# 0  [kron, aubree, gordon, university, michigan, c...
# 1  [international, health, officials, speeding, w...
# 2  [leading_edge, research, firm_focused, active,...
# 3  [mr, kennedy, safe, territory, reporting, cdc,...
# 4  [kylie, stevens, stephen, gibbs, nic, white, d...
#
#                                            glove_avg
# 0  [0.14527764461177867, 1.301592749657575, 0.487...
# 1  [0.4456857605208643, 1.4679776202002541, 0.697...
# 2  [-0.012559317511040717, 0.5841067982127425, 0....
# 3  [1.2950098205753602, 3.404326125156658, 2.0269...
# 4  [0.23033713073586115, 4.3884405878634425, 4.87...
#
# [5 rows x 24 columns]

# %%
df['article_text_cleaned_string'] = df['article_text_cleaned'].apply(lambda x: ' '.join(x))
docs = list(df['article_text_cleaned_string']) # a list where each document is a string

# labels = list(df['id_str'])
labels = list(range(len(df)))

sentences = TaggedDocumentIterator(docs, labels)

# %%
model = Doc2Vec(vector_size=100,
                 window=5,
                 min_count=20,
                 workers=2,
                 epochs=100,
                 dm=1,        #1 = paragraph vector - distributed memory; 0 = dbow
                 seed=42)

# %%
# train model
model.build_vocab(sentences)

# %%
model.train(sentences,
            total_examples=model.corpus_count,
            epochs=model.epochs, 
            )
# Out:
# WARNING:gensim.models.base_any2vec:Effective 'alpha' higher than previous training cycles

# %%
MODEL_PATH = './models/'
model_name = 'd2v_pv.model'

model.save(MODEL_PATH + model_name)

# %%
model.infer_vector(df['article_text_cleaned'][0]) # one document as a list of strings
# Out:
# array([-3.81713500e-03, -3.02705192e-03,  3.95734236e-03, -1.07510528e-03,
#         3.87954619e-03,  3.68858757e-03,  4.76369634e-03,  2.89270538e-03,
#        -8.39679968e-04,  3.80937057e-03,  4.13925899e-03,  4.03762190e-03,
#         4.31357929e-03, -4.61425120e-03,  2.92414887e-04,  9.13685290e-05,
#        -3.65538150e-03, -3.83670162e-03,  2.43769912e-03,  1.88678037e-03,
#        -3.34629673e-03,  1.92392373e-03, -4.99365805e-03, -3.61639541e-03,
#        -4.57807211e-03,  3.64909600e-03,  1.60619745e-03, -4.83668037e-03,
#         4.78581106e-03, -2.20841239e-03,  4.38499672e-04,  2.25511496e-03,
#        -4.99070762e-03,  2.69463897e-04,  2.97399762e-04,  4.98123839e-03,
#         1.44247664e-03,  3.32286814e-03,  1.67207245e-03, -3.27352365e-03,
#        -2.43683346e-03,  3.66754574e-03, -2.53688404e-03,  1.51808723e-03,
#        -3.93362110e-03,  3.61599750e-03, -3.65189346e-03, -4.44446364e-03,
#         3.59915383e-03,  2.27528391e-03, -3.78898985e-04,  4.33972804e-03,
#        -3.10815126e-03, -1.79580459e-03, -1.91141164e-03,  4.22634697e-03,
#        -1.23021647e-03, -2.15690723e-03, -4.87915659e-03,  1.27909216e-03,
#         1.30057579e-03,  1.65437022e-03,  4.50483523e-03,  2.31804885e-03,
#         4.56131995e-03,  4.95973101e-04,  4.78373747e-03,  1.84914819e-03,
#         1.88963220e-03,  1.55549461e-03, -3.26299982e-04,  3.59438080e-03,
#         4.25713370e-03,  1.44986610e-03, -2.95925909e-03,  4.29397635e-03,
#         8.83452769e-04,  3.38642829e-04, -4.72280692e-04,  2.25296454e-03,
#         2.50958884e-03, -4.84495284e-03,  2.65951268e-03, -1.92169799e-03,
#         1.09012966e-04,  4.88113984e-03,  4.31254040e-03,  4.41979943e-03,
#         6.65459156e-05,  3.54489381e-03, -3.65662109e-03,  3.35974852e-04,
#         1.82968378e-03, -3.89165990e-03,  1.89266936e-03, -6.72494527e-04,
#         3.64529947e-03, -1.91100815e-03,  1.13635848e-03,  2.06200732e-03],
#       dtype=float32)

# %%
df['d2v'] = df['article_text_cleaned'].apply(lambda x: model.infer_vector(x))

# %%
### save df

DATA_PATH = './data/cleaned/'
DF_NAME = 'concatenated_df_cleaned_glove_and_d2v.pkl'

with open(DATA_PATH + DF_NAME, 'wb') as f:
    pickle.dump(df, f)
